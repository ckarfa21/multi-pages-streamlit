# %% [markdown]
# # streamlit-multiapps

# %% [markdown]
# Un framework simple en python pour créer une application web multi-pages en utilisant streamlit.

# %% [markdown]
# # Installation de streamlit.

# %% [markdown]
# pip install --upgrade streamlit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# streamlit version.

# %% [markdown]
# streamlit hello.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Accés à la page d'accueil .

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Premiere page home avec accés aux données,deuxieme avec la data et la troisiéme avec les graphes .
